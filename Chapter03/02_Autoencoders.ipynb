# %% [markdown]
# # 오토인코더

# %% [markdown]
# 여기서는 간단한 오토인코더를 만들고, 학습하는 방법에 대해 설명한다.
#
# 이어서 오토인코더를 노이즈에 대해 강력하게 만드는 방법에 대해 알아본다.

# %% [markdown]
# ### 데이터셋 불러오기

# %%
import tensorflow as tf

# %%
from tensorflow.keras.datasets import fashion_mnist

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

print (x_train.shape)
print (x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
from matplotlib import pyplot as plt

# %%
classes = {
    0:"T-shirt/top",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle boot", 
}

# %%
n = 6
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(x_test[i])
    plt.title(classes[y_test[i]])
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# plt.savefig("TrainingSet.png")

# %% [markdown]
# ### 오토인코더 생성

# %%
from tensorflow.keras.layers import Flatten, Conv2D, Dropout, MaxPooling2D, UpSampling2D, Input

# %%
from tensorflow.keras import Model

# %%
input_img = Input(shape=(28, 28, 1))

x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)

# %%
Model(input_img, encoded).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 8)           584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 8)           0
# =================================================================
# Total params: 1,904
# Trainable params: 1,904
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
from tensorflow.keras.callbacks import TensorBoard

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 39s 82ms/step - loss: 0.4421 - val_loss: 0.3111
# Epoch 2/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.3066 - val_loss: 0.3027
# Epoch 3/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2995 - val_loss: 0.2989
# Epoch 4/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.2956 - val_loss: 0.2961
# Epoch 5/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.2936 - val_loss: 0.2942
# Epoch 6/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2917 - val_loss: 0.2924
# Epoch 7/50
# 469/469 [==============================] - 35s 76ms/step - loss: 0.2897 - val_loss: 0.2911
# Epoch 8/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2887 - val_loss: 0.2903
# Epoch 9/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2878 - val_loss: 0.2891
# Epoch 10/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2869 - val_loss: 0.2887
# Epoch 11/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2859 - val_loss: 0.2875
# Epoch 12/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2848 - val_loss: 0.2868
# Epoch 13/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2850 - val_loss: 0.2870
# Epoch 14/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2836 - val_loss: 0.2858
# Epoch 15/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2834 - val_loss: 0.2854
# Epoch 16/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2827 - val_loss: 0.2850
# Epoch 17/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2834 - val_loss: 0.2846
# Epoch 18/50
# 469/469 [==============================] - 35s 76ms/step - loss: 0.2825 - val_loss: 0.2846
# Epoch 19/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2824 - val_loss: 0.2847
# Epoch 20/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2822 - val_loss: 0.2837
# Epoch 21/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2810 - val_loss: 0.2834
# Epoch 22/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2814 - val_loss: 0.2834
# Epoch 23/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2810 - val_loss: 0.2829
# Epoch 24/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2805 - val_loss: 0.2826
# Epoch 25/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2801 - val_loss: 0.2826
# Epoch 26/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2811 - val_loss: 0.2824
# Epoch 27/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2803 - val_loss: 0.2822
# Epoch 28/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2802 - val_loss: 0.2824
# Epoch 29/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2796 - val_loss: 0.2819
# Epoch 30/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2787 - val_loss: 0.2818
# Epoch 31/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2793 - val_loss: 0.2815
# Epoch 32/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2791 - val_loss: 0.2814
# Epoch 33/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2792 - val_loss: 0.2809
# Epoch 34/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2789 - val_loss: 0.2809
# Epoch 35/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2784 - val_loss: 0.2805
# Epoch 36/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2780 - val_loss: 0.2805
# Epoch 37/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2782 - val_loss: 0.2803
# Epoch 38/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2781 - val_loss: 0.2801
# Epoch 39/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2785 - val_loss: 0.2801
# Epoch 40/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2779 - val_loss: 0.2798
# Epoch 41/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2775 - val_loss: 0.2797
# Epoch 42/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2778 - val_loss: 0.2799
# Epoch 43/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2773 - val_loss: 0.2794
# Epoch 44/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2768 - val_loss: 0.2795
# Epoch 45/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2775 - val_loss: 0.2794
# Epoch 46/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2766 - val_loss: 0.2791
# Epoch 47/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2777 - val_loss: 0.2790
# Epoch 48/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2761 - val_loss: 0.2789
# Epoch 49/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2765 - val_loss: 0.2794
# Epoch 50/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2770 - val_loss: 0.2786

# %%
autoencoder.save("./data/Batch50.p")
# Out:
# INFO:tensorflow:Assets written to: ./data/Batch50.p\assets

# %%
from tensorflow.keras.models import load_model

# %%
autoencoder_first = load_model("./data/Batch50.p")

# %%
decoded_imgs = autoencoder_first.predict(x_test)

n = 6
plt.figure(figsize=(20, 7))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
from tensorflow.keras.optimizers import Adam

# %%
autoencoder.compile(optimizer=Adam(learning_rate=0.0005), loss='binary_crossentropy')

# %%
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2776 - val_loss: 0.2785
# Epoch 2/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2770 - val_loss: 0.2785
# Epoch 3/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2760 - val_loss: 0.2784
# Epoch 4/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2764 - val_loss: 0.2783
# Epoch 5/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2760 - val_loss: 0.2784
# Epoch 6/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2763 - val_loss: 0.2782
# Epoch 7/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2764 - val_loss: 0.2782
# Epoch 8/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2760 - val_loss: 0.2780
# Epoch 9/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2757 - val_loss: 0.2781
# Epoch 10/50
# 469/469 [==============================] - 35s 76ms/step - loss: 0.2758 - val_loss: 0.2779
# Epoch 11/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2757 - val_loss: 0.2781
# Epoch 12/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2756 - val_loss: 0.2779
# Epoch 13/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2755 - val_loss: 0.2779
# Epoch 14/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2754 - val_loss: 0.2778
# Epoch 15/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2759 - val_loss: 0.2778
# Epoch 16/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2757 - val_loss: 0.2776
# Epoch 17/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2748 - val_loss: 0.2777
# Epoch 18/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2755 - val_loss: 0.2778
# Epoch 19/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2761 - val_loss: 0.2776
# Epoch 20/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2748 - val_loss: 0.2775
# Epoch 21/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2752 - val_loss: 0.2776
# Epoch 22/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2750 - val_loss: 0.2774
# Epoch 23/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2753 - val_loss: 0.2774
# Epoch 24/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2755 - val_loss: 0.2775
# Epoch 25/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2748 - val_loss: 0.2772
# Epoch 26/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2757 - val_loss: 0.2773
# Epoch 27/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2750 - val_loss: 0.2774
# Epoch 28/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2753 - val_loss: 0.2774
# Epoch 29/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2744 - val_loss: 0.2771
# Epoch 30/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2752 - val_loss: 0.2772
# Epoch 31/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2750 - val_loss: 0.2771
# Epoch 32/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2747 - val_loss: 0.2770
# Epoch 33/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2755 - val_loss: 0.2770
# Epoch 34/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2751 - val_loss: 0.2770
# Epoch 35/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2749 - val_loss: 0.2770
# Epoch 36/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2754 - val_loss: 0.2770
# Epoch 37/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2746 - val_loss: 0.2769
# Epoch 38/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2752 - val_loss: 0.2768
# Epoch 39/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2746 - val_loss: 0.2769
# Epoch 40/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2747 - val_loss: 0.2768
# Epoch 41/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2742 - val_loss: 0.2772
# Epoch 42/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2746 - val_loss: 0.2767
# Epoch 43/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2749 - val_loss: 0.2767
# Epoch 44/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2744 - val_loss: 0.2766
# Epoch 45/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2754 - val_loss: 0.2767
# Epoch 46/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2748 - val_loss: 0.2768
# Epoch 47/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2748 - val_loss: 0.2766
# Epoch 48/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2747 - val_loss: 0.2766
# Epoch 49/50
# 469/469 [==============================] - 36s 76ms/step - loss: 0.2735 - val_loss: 0.2765
# Epoch 50/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2740 - val_loss: 0.2765

# %%
autoencoder.save("./data/Batch100.p")
# Out:
# INFO:tensorflow:Assets written to: ./data/Batch100.p\assets

# %%
decoded_imgs = autoencoder.predict(x_test)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ### 임베딩

# %% [markdown]
# 오토인코더 중앙의 압축된 표현을 얻기 위해 학습을 진행했다. 이것을 TSNE를 활용하여 살펴보자.

# %%
embeddings = Model(input_img, Flatten()(encoded)).predict(x_test)

# %%
from sklearn.manifold import TSNE
import numpy as np

# %%
tsne = TSNE(n_components=2)

# %%
emb2d = tsne.fit_transform(embeddings)

# %%
x,y = np.squeeze(emb2d[:, 0]), np.squeeze(emb2d[:, 1])

# %%
import pandas as pd

# %%
from matplotlib.cm import tab10

# %%
summary =  pd.DataFrame({"x": x, "y": y, "target": y_test, "size": 10})

plt.figure(figsize=(10,8))

for key, sel in summary.groupby("target"):
    plt.scatter(sel["x"], sel["y"], s=10, color=tab10.colors[key], label=classes[key])
    
plt.legend()
plt.axis("off")
# Out:
# (-96.65089569091796, 93.07949981689453, -88.44893379211426, 98.95803565979004)

# %% [markdown]
# ### 노이즈 제거

# %% [markdown]
# 보다 강인한 오토인코더 모델을 만드는 방법을 소개한다.

# %%
from tensorflow.keras.layers import GaussianNoise

# %%
input_img = Input(shape=(28, 28, 1))

noisy_input = GaussianNoise(0.1)(input_img)

x = Conv2D(16, (3, 3), activation='relu', padding='same')(noisy_input)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

noisy_autoencoder = Model(input_img, decoded)

# %%
noisy_autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
noisy_autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test, x_test),
                callbacks=[TensorBoard(log_dir='/tmp/noisy_autoencoder')])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.4344 - val_loss: 0.3159
# Epoch 2/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.3069 - val_loss: 0.3035
# Epoch 3/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2998 - val_loss: 0.2989
# Epoch 4/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2964 - val_loss: 0.2964
# Epoch 5/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2946 - val_loss: 0.2945
# Epoch 6/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2920 - val_loss: 0.2926
# Epoch 7/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2905 - val_loss: 0.2915
# Epoch 8/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2898 - val_loss: 0.2909
# Epoch 9/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2894 - val_loss: 0.2904
# Epoch 10/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2884 - val_loss: 0.2901
# Epoch 11/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2879 - val_loss: 0.2890
# Epoch 12/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2872 - val_loss: 0.2894
# Epoch 13/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2867 - val_loss: 0.2882
# Epoch 14/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2867 - val_loss: 0.2873
# Epoch 15/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2861 - val_loss: 0.2870
# Epoch 16/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2859 - val_loss: 0.2870
# Epoch 17/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2855 - val_loss: 0.2868
# Epoch 18/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2855 - val_loss: 0.2862
# Epoch 19/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.2852 - val_loss: 0.2861
# Epoch 20/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.2840 - val_loss: 0.2867
# Epoch 21/50
# 469/469 [==============================] - 39s 83ms/step - loss: 0.2843 - val_loss: 0.2852
# Epoch 22/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.2831 - val_loss: 0.2850
# Epoch 23/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.2846 - val_loss: 0.2850
# Epoch 24/50
# 469/469 [==============================] - 38s 81ms/step - loss: 0.2839 - val_loss: 0.2846
# Epoch 25/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.2830 - val_loss: 0.2844
# Epoch 26/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.2835 - val_loss: 0.2846
# Epoch 27/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.2832 - val_loss: 0.2846
# Epoch 28/50
# 469/469 [==============================] - 36s 77ms/step - loss: 0.2827 - val_loss: 0.2840
# Epoch 29/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.2822 - val_loss: 0.2840
# Epoch 30/50
# 469/469 [==============================] - 38s 82ms/step - loss: 0.2832 - val_loss: 0.2836
# Epoch 31/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.2823 - val_loss: 0.2835
# Epoch 32/50
# 469/469 [==============================] - 38s 80ms/step - loss: 0.2821 - val_loss: 0.2840
# Epoch 33/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.2823 - val_loss: 0.2835
# Epoch 34/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.2822 - val_loss: 0.2834
# Epoch 35/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2819 - val_loss: 0.2828
# Epoch 36/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.2815 - val_loss: 0.2832
# Epoch 37/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2818 - val_loss: 0.2827
# Epoch 38/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.2818 - val_loss: 0.2828
# Epoch 39/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.2807 - val_loss: 0.2825
# Epoch 40/50
# 469/469 [==============================] - 37s 80ms/step - loss: 0.2812 - val_loss: 0.2825
# Epoch 41/50
# 469/469 [==============================] - 37s 79ms/step - loss: 0.2808 - val_loss: 0.2826
# Epoch 42/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2815 - val_loss: 0.2823
# Epoch 43/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2806 - val_loss: 0.2823
# Epoch 44/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.2807 - val_loss: 0.2823
# Epoch 45/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2805 - val_loss: 0.2821
# Epoch 46/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2811 - val_loss: 0.2819
# Epoch 47/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2808 - val_loss: 0.2817
# Epoch 48/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2797 - val_loss: 0.2819
# Epoch 49/50
# 469/469 [==============================] - 36s 78ms/step - loss: 0.2810 - val_loss: 0.2815
# Epoch 50/50
# 469/469 [==============================] - 37s 78ms/step - loss: 0.2802 - val_loss: 0.2821

# %%
autoencoder.save("./data/DenoisingAutoencoder.p")
# Out:
# INFO:tensorflow:Assets written to: ./data/DenoisingAutoencoder.p\assets

# %%
noise_factor = 0.1
x_train_noisy = x_train + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_train.shape) 
x_test_noisy = x_test + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=x_test.shape) 

x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

# %%
decoded_imgs = autoencoder.predict(x_test_noisy)

decoded_imgs_denoised = noisy_autoencoder.predict(x_test_noisy)

n = 6
plt.figure(figsize=(20, 10))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(3, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==0:
        plt.ylabel("Original")
    else:
        ax.get_yaxis().set_visible(False)
        
    # Display reconstruction
    ax = plt.subplot(3, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==0:
        plt.ylabel("Vanilla Autoencoder")
    else:
        ax.get_yaxis().set_visible(False)
     
    ax = plt.subplot(3, n, i + 2*n)
    plt.imshow(decoded_imgs_denoised[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    if i==0:
        plt.ylabel("Denoising Autoencoder")
    else:
        ax.get_yaxis().set_visible(False)
    
        
plt.show()

# %%
decoded_imgs = noisy_autoencoder.predict(x_test_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
